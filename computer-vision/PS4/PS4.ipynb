# %%
import numpy as np
import cv2
from tools import PlotTools, harris, sobel
import pylab
pylab.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
img = cv2.imread('inputs/check.bmp')[:, :, 2]
grad_x, grad_y = sobel.compute_gradients(img)
img_sobel = sobel.get_sobel(grad_x, grad_y)
PlotTools.display_and_save(sobel.normalize(img_sobel), "out/sobel_check.bmp")
PlotTools.display_and_save(sobel.normalize(grad_x), "out/gradx_check.bmp")
PlotTools.display_and_save(sobel.normalize(grad_y), "out/grady_check.bmp")

# %%
R = harris.harris_cuda_caller(grad_x, grad_y, wd=5, alpha=0.05)
PlotTools.display_img(R)
# Out:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# <ipython-input-3-ede985794d3c> in <module>()
# ----> 1 R = harris.harris_cuda_caller(grad_x, grad_y, wd=5, alpha=0.05)
#       2 PlotTools.display_img(R)
#
# ~/usr/vendors/anaconda3/lib/python3.6/site-packages/numba/cuda/compiler.py in __call__(self, *args)
#     699         Specialize and invoke this kernel with *args*.
#     700         '''
# --> 701         kernel = self.specialize(*args)
#     702         cfg = kernel[self.griddim, self.blockdim, self.stream, self.sharedmem]
#     703         cfg(*args)
#
# ~/usr/vendors/anaconda3/lib/python3.6/site-packages/numba/cuda/compiler.py in specialize(self, *args)
#     710         argtypes = tuple(
#     711             [self.typingctx.resolve_argument_type(a) for a in args])
# --> 712         kernel = self.compile(argtypes)
#     713         return kernel
#     714
#
# ...

# %%
img = cv2.imread('inputs/check_rot.bmp')[:, :, 2]
grad_x, grad_y = sobel.compute_gradients(img)
img_sobel = sobel.get_sobel(grad_x, grad_y)
PlotTools.display_and_save(sobel.normalize(img_sobel), "out/sobel_check_rot.bmp")
PlotTools.display_and_save(sobel.normalize(grad_x), "out/gradx_check_rot.bmp")
PlotTools.display_and_save(sobel.normalize(grad_y), "out/grady_check_rot.bmp")

# %%
R = harris.harris_cuda_caller(grad_x, grad_y, wd=5, alpha=0.05)
PlotTools.display_img(R)
# Out:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# <ipython-input-5-ede985794d3c> in <module>()
# ----> 1 R = harris.harris_cuda_caller(grad_x, grad_y, wd=5, alpha=0.05)
#       2 PlotTools.display_img(R)
#
# ~/usr/vendors/anaconda3/lib/python3.6/site-packages/numba/cuda/compiler.py in __call__(self, *args)
#     699         Specialize and invoke this kernel with *args*.
#     700         '''
# --> 701         kernel = self.specialize(*args)
#     702         cfg = kernel[self.griddim, self.blockdim, self.stream, self.sharedmem]
#     703         cfg(*args)
#
# ~/usr/vendors/anaconda3/lib/python3.6/site-packages/numba/cuda/compiler.py in specialize(self, *args)
#     710         argtypes = tuple(
#     711             [self.typingctx.resolve_argument_type(a) for a in args])
# --> 712         kernel = self.compile(argtypes)
#     713         return kernel
#     714
#
# ...

# %%
img = cv2.imread('inputs/simA.jpg')[:, :, 2]
grad_x, grad_y = sobel.compute_gradients(img)
harris_img = harris.harris_cuda_caller(grad_x, grad_y, wd=5, alpha=0.05)
PlotTools.display_img(harris_img)
# Out:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# <ipython-input-6-a356ce053d53> in <module>()
#       1 img = cv2.imread('inputs/simA.jpg')[:, :, 2]
#       2 grad_x, grad_y = sobel.compute_gradients(img)
# ----> 3 harris_img = harris.harris_cuda_caller(grad_x, grad_y, wd=5, alpha=0.05)
#       4 PlotTools.display_img(harris_img)
#
# ~/usr/vendors/anaconda3/lib/python3.6/site-packages/numba/cuda/compiler.py in __call__(self, *args)
#     699         Specialize and invoke this kernel with *args*.
#     700         '''
# --> 701         kernel = self.specialize(*args)
#     702         cfg = kernel[self.griddim, self.blockdim, self.stream, self.sharedmem]
#     703         cfg(*args)
#
# ~/usr/vendors/anaconda3/lib/python3.6/site-packages/numba/cuda/compiler.py in specialize(self, *args)
#     710         argtypes = tuple(
# ...

# %%
maxi = np.max(img)
harris_img_filtered = np.vectorize(lambda x: x if (x > 0.2*maxi) else 0 )(harris_img)
PlotTools.display_img(harris_img_filtered)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-46e68e7a5808> in <module>()
#       1 maxi = np.max(img)
# ----> 2 harris_img_filtered = np.vectorize(lambda x: x if (x > 0.2*maxi) else 0 )(harris_img)
#       3 PlotTools.display_img(harris_img_filtered)
#
# NameError: name 'harris_img' is not defined
